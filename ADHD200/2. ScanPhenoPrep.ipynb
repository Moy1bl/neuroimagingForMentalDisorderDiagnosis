# %% [markdown]
# # Preparing the Scan Files for Exploration and Analysis

# %% [markdown]
# ### Libraries

# %%
from nilearn import plotting, image
from nilearn.input_data import NiftiMasker
import nibabel as nib
from bids import BIDSLayout, BIDSValidator
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import FastICA
from nilearn.image import index_img
from nipype.interfaces import fsl
from nipype.pipeline.engine import Workflow, Node
from nipype import Workflow, Node
from nipype.interfaces.fsl import MCFLIRT
import os
from scipy.stats import ttest_ind
import pandas as pd
import collections
from ydata_profiling import ProfileReport
import random
# Out:
# /usr/local/lib/python3.10/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
base_dir = '/Volumes/Expansion/ADHD/yomo-20231204_124111'

# %%
# Not the nicest function, but it works to extract every nifti files from the dataset
# .. despite the lack of standardization in the folder structure
# i.e., some records have multiple rest files
def load_fmri_data_with_metadata(base_dir):
    fmri_records = []
    for subject_folder in os.listdir(base_dir):
        subject_path = os.path.join(base_dir, subject_folder)
        if os.path.isdir(subject_path):
            # Search for any subdirectories that contain 'anat', 'rest', or 'func'
            for dir_name in os.listdir(subject_path):
                if any(scan_type in dir_name for scan_type in ['anat', 'rest', 'func']):
                    scan_path = os.path.join(subject_path, dir_name)
                    nifti_path = os.path.join(scan_path, 'NIfTI')
                    if os.path.isdir(nifti_path):
                        for file in os.listdir(nifti_path):
                            if file.endswith('.nii.gz') and not file.startswith('.'):
                                file_path = os.path.join(nifti_path, file)
                                fmri_records.append({
                                    "subject_id": subject_folder,
                                    "scan_type": dir_name,
                                    "file_path": file_path
                                })
    return pd.DataFrame(fmri_records)

fmri_data_df = load_fmri_data_with_metadata(base_dir)

# %%
fmri_data_df
# Out:
#                 subject_id scan_type  \
# 0     NeuroIMAGE_4020830_1    rest_1
# 1     NeuroIMAGE_4020830_1    anat_1
# 2         Peking_3248920_1    rest_1
# 3         Peking_3248920_1    anat_1
# 4         Peking_3767334_1    rest_1
# ...                    ...       ...
# 2383           NYU_10032_1    rest_1
# 2384           NYU_10032_1    anat_1
# 2385           NYU_10030_1    rest_2
# 2386           NYU_10030_1    rest_1
# 2387           NYU_10030_1    anat_1
#
#                                               file_path
# 0     /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 1     /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2     /Volumes/Expansion/ADHD/yomo-20231204_124111/P...
# 3     /Volumes/Expansion/ADHD/yomo-20231204_124111/P...
# 4     /Volumes/Expansion/ADHD/yomo-20231204_124111/P...
# ...                                                 ...
# 2383  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2384  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2385  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2386  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2387  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
#
# [2388 rows x 3 columns]

# %%
# Split 'subject_id' into three parts
splits = fmri_data_df['subject_id'].str.split('_', expand=True)

# Assign the split parts to new columns
fmri_data_df['site'] = splits[0]
fmri_data_df['ID'] = splits[1]
fmri_data_df['session'] = splits[2]

# %%
# Reorder columns
fmri_data_df = fmri_data_df[['ID', 'site', 'session', 'subject_id', 'scan_type', 'file_path']]

# Rename 'subject_id' to 'combinedData'
fmri_data_df = fmri_data_df.rename(columns={'subject_id': 'combinedData'})
fmri_data_df.head()
# Out:
#         ID        site session          combinedData scan_type  \
# 0  4020830  NeuroIMAGE       1  NeuroIMAGE_4020830_1    rest_1
# 1  4020830  NeuroIMAGE       1  NeuroIMAGE_4020830_1    anat_1
# 2  3248920      Peking       1      Peking_3248920_1    rest_1
# 3  3248920      Peking       1      Peking_3248920_1    anat_1
# 4  3767334      Peking       1      Peking_3767334_1    rest_1
#
#                                            file_path
# 0  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 1  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...
# 2  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...
# 3  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...
# 4  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...

# %%
# A total of 2388 scans from 973 unique subjects
fmri_data_df.shape
# Out:
# (2388, 6)

# %%
labels_df = pd.read_csv('/Volumes/Expansion/ADHD/yomo-20231204_124111/adhd200_preprocessed_phenotypics.tsv', sep='\t')

# %%
labels_df['DX'].value_counts()
# Out:
# DX
# 0          585
# 1          212
# 3          137
# pending     26
# 2           13
# Name: count, dtype: int64

# %%
# For simplicity, we will only consider ADHD vs. Healthy controls and not the subtypes
def binary_label(dx_value):
    if dx_value == '0':
        return 0
    elif dx_value in ['1', '2', '3']:
        return 1
    elif dx_value == 'pending':
        return np.nan
    else:
        return None  # or some default value

labels_df['diagnosis'] = labels_df['DX'].map(binary_label)

# %%
labels_df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0.0    585
# 1.0    362
# Name: count, dtype: int64

# %%
labels_df.head()
# Out:
#    ScanDir ID  Site  Gender    Age Handedness DX   Secondary Dx ADHD Measure  \
# 0     2371032     3     0.0  10.73          1  0            NaN            2
# 1     2026113     3     0.0  12.99          1  1            NaN            2
# 2     3434578     3     0.0   8.12          1  0            NaN            2
# 3     8628223     3     0.0  10.81          1  0  Simple phobia            2
# 4     1623716     3     0.0  12.65          1  1            NaN            2
#
#   ADHD Index Inattentive Hyper/Impulsive  IQ Measure  Verbal IQ  \
# 0         47          55              43         1.0      121.0
# 1         90          89              78         1.0      122.0
# 2         42          42              43         1.0       85.0
# 3         42          49              49         1.0       85.0
# 4         87          90              90         1.0       89.0
#
#    Performance IQ  Full2 IQ  Full4 IQ Med Status  QC_Athena  QC_NIAK  \
# 0           119.0       NaN     122.0          1        1.0      1.0
# 1           108.0       NaN     106.0          1        1.0      1.0
# 2            98.0       NaN      89.0          1        1.0      1.0
# 3            86.0       NaN      97.0          1        1.0      1.0
# 4            88.0       NaN      89.0          1        1.0      1.0
#
#    diagnosis
# 0        0.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        1.0

# %%
labels_df.shape
# Out:
# (973, 20)

# %%
fmri_data_df.shape
# Out:
# (2388, 6)

# %%
fmri_data_df['ID'] = fmri_data_df['ID'].astype('int64')

# %%
# Merging the labels and pheno data
merged_df = pd.merge(fmri_data_df, labels_df, left_on='ID', right_on='ScanDir ID', how='left')
merged_df.head()
# Out:
#         ID        site session          combinedData scan_type  \
# 0  4020830  NeuroIMAGE       1  NeuroIMAGE_4020830_1    rest_1
# 1  4020830  NeuroIMAGE       1  NeuroIMAGE_4020830_1    anat_1
# 2  3248920      Peking       1      Peking_3248920_1    rest_1
# 3  3248920      Peking       1      Peking_3248920_1    anat_1
# 4  3767334      Peking       1      Peking_3767334_1    rest_1
#
#                                            file_path  ScanDir ID  Site  \
# 0  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...     4020830     4
# 1  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...     4020830     4
# 2  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3248920     1
# 3  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3248920     1
# 4  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3767334     1
#
#    Gender    Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 0     0.0  18.19  ...             NaN        NaN       NaN            NaN
# 1     0.0  18.19  ...             NaN        NaN       NaN            NaN
# 2     1.0  12.17  ...              10        3.0    -999.0         -999.0
# 3     1.0  12.17  ...              10        3.0    -999.0         -999.0
# 4     1.0   8.33  ...              25        3.0     112.0          104.0
#
#   Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 0      NaN      NaN        NaN        1.0      1.0        0.0
# 1      NaN      NaN        NaN        1.0      1.0        0.0
# 2      NaN   -999.0          1        1.0      1.0        0.0
# 3      NaN   -999.0          1        1.0      1.0        0.0
# 4   -999.0    109.0          1        1.0      1.0        1.0
#
# [5 rows x 26 columns]

# %%
merged_df.columns
# Out:
# Index(['ID', 'site', 'session', 'combinedData', 'scan_type', 'file_path',
#        'ScanDir ID', 'Site', 'Gender', 'Age', 'Handedness', 'DX',
#        'Secondary Dx', 'ADHD Measure', 'ADHD Index', 'Inattentive',
#        'Hyper/Impulsive', 'IQ Measure', 'Verbal IQ', 'Performance IQ',
#        'Full2 IQ', 'Full4 IQ', 'Med Status', 'QC_Athena', 'QC_NIAK',
#        'diagnosis'],
#       dtype='object')

# %%
merged_df.shape
# Out:
# (2388, 26)

# %%
# For some records we have more than 1 rest session for some reason (not discloused in the documentation)
merged_df['scan_type'].value_counts()
# Out:
# scan_type
# rest_1    980
# anat_1    973
# rest_2    307
# rest_3    114
# rest_4      6
# rest_6      4
# rest_5      4
# Name: count, dtype: int64

# %%
# Find the IDs for each rest category
ids_rest_2 = set(merged_df[merged_df['scan_type'] == 'rest_2']['ID'])
ids_rest_3 = set(merged_df[merged_df['scan_type'] == 'rest_3']['ID'])
ids_rest_4 = set(merged_df[merged_df['scan_type'] == 'rest_4']['ID'])
ids_rest_5 = set(merged_df[merged_df['scan_type'] == 'rest_5']['ID'])
ids_rest_6 = set(merged_df[merged_df['scan_type'] == 'rest_6']['ID'])

# Combine IDs for rest_3, rest_4, rest_5, and rest_6
ids_rest_3_to_6 = ids_rest_3.union(ids_rest_4, ids_rest_5, ids_rest_6)

# %%
# Double check if ids_rest_2 includes all ids from rest_3 to rest_6
# Logically, yes, as we won't have rest 2-6 without rest 2, but just to be sure
if ids_rest_3_to_6.issubset(ids_rest_2):
    print("All IDs from rest_3, rest_4, rest_5, and rest_6 are included in rest_2 IDs.")
else:
    print("There are some IDs in rest_3 to rest_6 that are not included in rest_2 IDs.")
# Out:
# All IDs from rest_3, rest_4, rest_5, and rest_6 are included in rest_2 IDs.

# %%
# Filter the DataFrame
filtered_for_diagnosis = merged_df[merged_df['ID'].isin(ids_rest_2)]

# Display the ID and diagnosis columns
print(filtered_for_diagnosis[['ID', 'diagnosis']])
# Out:
#            ID  diagnosis
# 8     1340333        1.0
# 9     1340333        1.0
# 10    1340333        1.0
# 11    1340333        1.0
# 18    3560456        1.0
# ...       ...        ...
# 2381  3470141        1.0
# 2382  3470141        1.0
# 2385    10030        1.0
# 2386    10030        1.0
# 2387    10030        1.0
#
# [1047 rows x 2 columns]

# %%
filtered_for_diagnosis
# Out:
#            ID  site session    combinedData scan_type  \
# 8     1340333  OHSU       1  OHSU_1340333_1    rest_3
# 9     1340333  OHSU       1  OHSU_1340333_1    rest_2
# 10    1340333  OHSU       1  OHSU_1340333_1    rest_1
# 11    1340333  OHSU       1  OHSU_1340333_1    anat_1
# 18    3560456  OHSU       1  OHSU_3560456_1    rest_3
# ...       ...   ...     ...             ...       ...
# 2381  3470141  OHSU       1  OHSU_3470141_1    rest_1
# 2382  3470141  OHSU       1  OHSU_3470141_1    anat_1
# 2385    10030   NYU       1     NYU_10030_1    rest_2
# 2386    10030   NYU       1     NYU_10030_1    rest_1
# 2387    10030   NYU       1     NYU_10030_1    anat_1
#
#                                               file_path  ScanDir ID  Site  \
# 8     /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     1340333     6
# 9     /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     1340333     6
# 10    /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     1340333     6
# 11    /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     1340333     6
# 18    /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     3560456     6
# ...                                                 ...         ...   ...
# 2381  /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     3470141     6
# 2382  /Volumes/Expansion/ADHD/yomo-20231204_124111/O...     3470141     6
# 2385  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...       10030     5
# 2386  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...       10030     5
# 2387  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...       10030     5
#
#       Gender    Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 8        0.0   7.42  ...              90        2.0       NaN            NaN
# 9        0.0   7.42  ...              90        2.0       NaN            NaN
# 10       0.0   7.42  ...              90        2.0       NaN            NaN
# 11       0.0   7.42  ...              90        2.0       NaN            NaN
# 18       0.0   7.83  ...              63        2.0       NaN            NaN
# ...      ...    ...  ...             ...        ...       ...            ...
# 2381     1.0   8.50  ...              90        2.0       NaN            NaN
# 2382     1.0   8.50  ...              90        2.0       NaN            NaN
# 2385     1.0  12.41  ...              72        2.0     100.0          105.0
# 2386     1.0  12.41  ...              72        2.0     100.0          105.0
# 2387     1.0  12.41  ...              72        2.0     100.0          105.0
#
#      Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 8         NaN     98.0          2        1.0      1.0        1.0
# 9         NaN     98.0          2        1.0      1.0        1.0
# 10        NaN     98.0          2        1.0      1.0        1.0
# 11        NaN     98.0          2        1.0      1.0        1.0
# 18        NaN    126.0       -999        0.0      0.0        1.0
# ...       ...      ...        ...        ...      ...        ...
# 2381      NaN    104.0          2        1.0      1.0        1.0
# 2382      NaN    104.0          2        1.0      1.0        1.0
# 2385      NaN    103.0       -999        1.0      1.0        1.0
# 2386      NaN    103.0       -999        1.0      1.0        1.0
# 2387      NaN    103.0       -999        1.0      1.0        1.0
#
# [1047 rows x 26 columns]

# %%
# Get unique IDs and their diagnosis
unique_diagnosis_original = merged_df.drop_duplicates(subset='ID')[['ID', 'diagnosis']]

# Get diagnosis distribution
diagnosis_distribution_original = unique_diagnosis_original['diagnosis'].value_counts()
print("Diagnosis distribution in original dataset:")
print(diagnosis_distribution_original)
# Out:
# Diagnosis distribution in original dataset:
# diagnosis
# 0.0    585
# 1.0    362
# Name: count, dtype: int64

# %%
# Remove IDs with more than one rest session
cleaned = merged_df[~merged_df['ID'].isin(ids_rest_2)]

# Get unique IDs and their diagnosis in the cleaned dataset
unique_diagnosis_cleaned = cleaned.drop_duplicates(subset='ID')[['ID', 'diagnosis']]

# Get diagnosis distribution in the cleaned dataset
diagnosis_distribution_cleaned = unique_diagnosis_cleaned['diagnosis'].value_counts()
print("Diagnosis distribution in cleaned dataset:")
print(diagnosis_distribution_cleaned)
# Out:
# Diagnosis distribution in cleaned dataset:
# diagnosis
# 0.0    412
# 1.0    231
# Name: count, dtype: int64

# %%
cleaned = merged_df[~merged_df['ID'].isin(ids_rest_2)]
cleaned.shape
# Out:
# (1341, 26)

# %%
cleaned['session'] = cleaned['session'].astype('int64')
# Out:
# /var/folders/76/tz8l2rys40b0xrb06s1m7c640000gn/T/ipykernel_32479/3390855513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned['session'] = cleaned['session'].astype('int64')

# %%
filtered_rows = cleaned[cleaned['session'] > 1]
print(filtered_rows)
# Out:
#          ID   site  session   combinedData scan_type  \
# 1967  15022  WashU        2  WashU_15022_2    rest_1
# 1970  15021  WashU        2  WashU_15021_2    rest_1
# 1973  15024  WashU        2  WashU_15024_2    rest_1
# 1978  15023  WashU        2  WashU_15023_2    rest_1
# 2034  15011  WashU        2  WashU_15011_2    rest_1
# 2042  15013  WashU        2  WashU_15013_2    rest_1
# 2061  15014  WashU        2  WashU_15014_2    rest_1
# 2066  15017  WashU        2  WashU_15017_2    rest_1
# 2068  15016  WashU        2  WashU_15016_2    rest_1
# 2069  15016  WashU        2  WashU_15016_2    anat_1
# 2072  15019  WashU        2  WashU_15019_2    rest_1
#
#                                               file_path  ScanDir ID  Site  \
# 1967  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15022     8
# 1970  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15021     8
# 1973  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15024     8
# 1978  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15023     8
# 2034  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15011     8
# 2042  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15013     8
# 2061  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15014     8
# 2066  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15017     8
# 2068  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15016     8
# 2069  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15016     8
# 2072  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15019     8
#
#       Gender   Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 1967     1.0  9.17  ...             NaN        4.0       NaN            NaN
# 1970     0.0  7.52  ...             NaN        4.0       NaN            NaN
# 1973     1.0  7.25  ...             NaN        4.0       NaN            NaN
# 1978     0.0  7.77  ...             NaN        4.0       NaN            NaN
# 2034     1.0  7.26  ...             NaN        4.0       NaN            NaN
# 2042     0.0  7.67  ...             NaN        4.0       NaN            NaN
# 2061     0.0  7.09  ...             NaN        4.0       NaN            NaN
# 2066     1.0  8.02  ...             NaN        4.0       NaN            NaN
# 2068     1.0  8.30  ...             NaN        4.0       NaN            NaN
# 2069     1.0  8.30  ...             NaN        4.0       NaN            NaN
# 2072     1.0  8.28  ...             NaN        4.0       NaN            NaN
#
#      Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 1967      NaN    118.0        NaN        1.0      1.0        0.0
# 1970      NaN     86.0        NaN        1.0      1.0        0.0
# 1973      NaN    136.0        NaN        1.0      1.0        0.0
# 1978      NaN    119.0        NaN        1.0      1.0        0.0
# 2034      NaN    124.0        NaN        NaN      NaN        0.0
# 2042      NaN    117.0        NaN        1.0      1.0        0.0
# 2061      NaN    121.0        NaN        1.0      1.0        0.0
# 2066      NaN     98.0        NaN        1.0      1.0        0.0
# 2068      NaN     96.0        NaN        1.0      0.0        0.0
# 2069      NaN     96.0        NaN        1.0      0.0        0.0
# 2072      NaN    132.0        NaN        1.0      0.0        0.0
#
# [11 rows x 26 columns]

# %%
unique_vals = filtered_rows['ID'].nunique()

print(f"Number of unique values in 'ID': {unique_vals}")
# Out:
# Number of unique values in 'ID': 10

# %%
print(cleaned[cleaned['site']=='WashU'])
# Out:
#          ID   site  session   combinedData scan_type  \
# 1925  15038  WashU        1  WashU_15038_1    rest_1
# 1926  15038  WashU        1  WashU_15038_1    anat_1
# 1965  15022  WashU        1  WashU_15022_1    rest_1
# 1966  15022  WashU        1  WashU_15022_1    anat_1
# 1967  15022  WashU        2  WashU_15022_2    rest_1
# 1968  15021  WashU        1  WashU_15021_1    rest_1
# 1969  15021  WashU        1  WashU_15021_1    anat_1
# 1970  15021  WashU        2  WashU_15021_2    rest_1
# 1971  15024  WashU        1  WashU_15024_1    rest_1
# 1972  15024  WashU        1  WashU_15024_1    anat_1
# 1973  15024  WashU        2  WashU_15024_2    rest_1
# 1976  15023  WashU        1  WashU_15023_1    rest_1
# 1977  15023  WashU        1  WashU_15023_1    anat_1
# 1978  15023  WashU        2  WashU_15023_2    rest_1
# 1988  15025  WashU        1  WashU_15025_1    rest_1
# 1989  15025  WashU        1  WashU_15025_1    anat_1
# 2033  15011  WashU        1  WashU_15011_1    anat_1
# 2034  15011  WashU        2  WashU_15011_2    rest_1
# 2038  15010  WashU        1  WashU_15010_1    rest_1
# 2039  15010  WashU        1  WashU_15010_1    anat_1
# 2040  15013  WashU        1  WashU_15013_1    rest_1
# 2041  15013  WashU        1  WashU_15013_1    anat_1
# 2042  15013  WashU        2  WashU_15013_2    rest_1
# 2043  15012  WashU        1  WashU_15012_1    rest_1
# 2044  15012  WashU        1  WashU_15012_1    anat_1
# 2051  15015  WashU        1  WashU_15015_1    rest_1
# 2052  15015  WashU        1  WashU_15015_1    anat_1
# 2059  15014  WashU        1  WashU_15014_1    rest_1
# 2060  15014  WashU        1  WashU_15014_1    anat_1
# 2061  15014  WashU        2  WashU_15014_2    rest_1
# 2064  15017  WashU        1  WashU_15017_1    rest_1
# 2065  15017  WashU        1  WashU_15017_1    anat_1
# 2066  15017  WashU        2  WashU_15017_2    rest_1
# 2067  15016  WashU        1  WashU_15016_1    rest_1
# 2068  15016  WashU        2  WashU_15016_2    rest_1
# 2069  15016  WashU        2  WashU_15016_2    anat_1
# 2070  15019  WashU        1  WashU_15019_1    rest_1
# 2071  15019  WashU        1  WashU_15019_1    anat_1
# 2072  15019  WashU        2  WashU_15019_2    rest_1
#
#                                               file_path  ScanDir ID  Site  \
# 1925  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15038     8
# 1926  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15038     8
# 1965  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15022     8
# 1966  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15022     8
# 1967  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15022     8
# 1968  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15021     8
# 1969  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15021     8
# 1970  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15021     8
# 1971  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15024     8
# 1972  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15024     8
# 1973  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15024     8
# 1976  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15023     8
# 1977  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15023     8
# 1978  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15023     8
# 1988  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15025     8
# 1989  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15025     8
# 2033  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15011     8
# 2034  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15011     8
# 2038  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15010     8
# 2039  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15010     8
# 2040  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15013     8
# 2041  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15013     8
# 2042  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15013     8
# 2043  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15012     8
# 2044  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15012     8
# 2051  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15015     8
# 2052  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15015     8
# 2059  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15014     8
# 2060  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15014     8
# 2061  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15014     8
# 2064  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15017     8
# 2065  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15017     8
# 2066  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15017     8
# 2067  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15016     8
# 2068  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15016     8
# 2069  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15016     8
# 2070  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15019     8
# 2071  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15019     8
# 2072  /Volumes/Expansion/ADHD/yomo-20231204_124111/W...       15019     8
#
#       Gender    Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 1925     1.0  12.38  ...             NaN        4.0       NaN            NaN
# 1926     1.0  12.38  ...             NaN        4.0       NaN            NaN
# 1965     1.0   9.17  ...             NaN        4.0       NaN            NaN
# 1966     1.0   9.17  ...             NaN        4.0       NaN            NaN
# 1967     1.0   9.17  ...             NaN        4.0       NaN            NaN
# 1968     0.0   7.52  ...             NaN        4.0       NaN            NaN
# 1969     0.0   7.52  ...             NaN        4.0       NaN            NaN
# 1970     0.0   7.52  ...             NaN        4.0       NaN            NaN
# 1971     1.0   7.25  ...             NaN        4.0       NaN            NaN
# 1972     1.0   7.25  ...             NaN        4.0       NaN            NaN
# 1973     1.0   7.25  ...             NaN        4.0       NaN            NaN
# 1976     0.0   7.77  ...             NaN        4.0       NaN            NaN
# 1977     0.0   7.77  ...             NaN        4.0       NaN            NaN
# 1978     0.0   7.77  ...             NaN        4.0       NaN            NaN
# 1988     0.0   7.75  ...             NaN        4.0       NaN            NaN
# 1989     0.0   7.75  ...             NaN        4.0       NaN            NaN
# 2033     1.0   7.26  ...             NaN        4.0       NaN            NaN
# 2034     1.0   7.26  ...             NaN        4.0       NaN            NaN
# 2038     0.0   7.63  ...             NaN        4.0       NaN            NaN
# 2039     0.0   7.63  ...             NaN        4.0       NaN            NaN
# 2040     0.0   7.67  ...             NaN        4.0       NaN            NaN
# 2041     0.0   7.67  ...             NaN        4.0       NaN            NaN
# 2042     0.0   7.67  ...             NaN        4.0       NaN            NaN
# 2043     0.0   8.96  ...             NaN        4.0       NaN            NaN
# 2044     0.0   8.96  ...             NaN        4.0       NaN            NaN
# 2051     0.0   8.10  ...             NaN        4.0       NaN            NaN
# 2052     0.0   8.10  ...             NaN        4.0       NaN            NaN
# 2059     0.0   7.09  ...             NaN        4.0       NaN            NaN
# 2060     0.0   7.09  ...             NaN        4.0       NaN            NaN
# 2061     0.0   7.09  ...             NaN        4.0       NaN            NaN
# 2064     1.0   8.02  ...             NaN        4.0       NaN            NaN
# 2065     1.0   8.02  ...             NaN        4.0       NaN            NaN
# 2066     1.0   8.02  ...             NaN        4.0       NaN            NaN
# 2067     1.0   8.30  ...             NaN        4.0       NaN            NaN
# 2068     1.0   8.30  ...             NaN        4.0       NaN            NaN
# 2069     1.0   8.30  ...             NaN        4.0       NaN            NaN
# 2070     1.0   8.28  ...             NaN        4.0       NaN            NaN
# 2071     1.0   8.28  ...             NaN        4.0       NaN            NaN
# 2072     1.0   8.28  ...             NaN        4.0       NaN            NaN
#
#      Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 1925      NaN    128.0        NaN        0.0      0.0        0.0
# 1926      NaN    128.0        NaN        0.0      0.0        0.0
# 1965      NaN    118.0        NaN        1.0      1.0        0.0
# 1966      NaN    118.0        NaN        1.0      1.0        0.0
# 1967      NaN    118.0        NaN        1.0      1.0        0.0
# 1968      NaN     86.0        NaN        1.0      1.0        0.0
# 1969      NaN     86.0        NaN        1.0      1.0        0.0
# 1970      NaN     86.0        NaN        1.0      1.0        0.0
# 1971      NaN    136.0        NaN        1.0      1.0        0.0
# 1972      NaN    136.0        NaN        1.0      1.0        0.0
# 1973      NaN    136.0        NaN        1.0      1.0        0.0
# 1976      NaN    119.0        NaN        1.0      1.0        0.0
# 1977      NaN    119.0        NaN        1.0      1.0        0.0
# 1978      NaN    119.0        NaN        1.0      1.0        0.0
# 1988      NaN    114.0        NaN        1.0      1.0        0.0
# 1989      NaN    114.0        NaN        1.0      1.0        0.0
# 2033      NaN    124.0        NaN        NaN      NaN        0.0
# 2034      NaN    124.0        NaN        NaN      NaN        0.0
# 2038      NaN     99.0        NaN        1.0      1.0        0.0
# 2039      NaN     99.0        NaN        1.0      1.0        0.0
# 2040      NaN    117.0        NaN        1.0      1.0        0.0
# 2041      NaN    117.0        NaN        1.0      1.0        0.0
# 2042      NaN    117.0        NaN        1.0      1.0        0.0
# 2043      NaN    109.0        NaN        1.0      1.0        0.0
# 2044      NaN    109.0        NaN        1.0      1.0        0.0
# 2051      NaN    109.0        NaN        1.0      1.0        0.0
# 2052      NaN    109.0        NaN        1.0      1.0        0.0
# 2059      NaN    121.0        NaN        1.0      1.0        0.0
# 2060      NaN    121.0        NaN        1.0      1.0        0.0
# 2061      NaN    121.0        NaN        1.0      1.0        0.0
# 2064      NaN     98.0        NaN        1.0      1.0        0.0
# 2065      NaN     98.0        NaN        1.0      1.0        0.0
# 2066      NaN     98.0        NaN        1.0      1.0        0.0
# 2067      NaN     96.0        NaN        1.0      0.0        0.0
# 2068      NaN     96.0        NaN        1.0      0.0        0.0
# 2069      NaN     96.0        NaN        1.0      0.0        0.0
# 2070      NaN    132.0        NaN        1.0      0.0        0.0
# 2071      NaN    132.0        NaN        1.0      0.0        0.0
# 2072      NaN    132.0        NaN        1.0      0.0        0.0
#
# [39 rows x 26 columns]

# %%
nan_rows = cleaned[pd.isna(cleaned['diagnosis'])]
print(nan_rows)
# Out:
#         ID   site  session   combinedData scan_type  \
# 22   26005  Brown        1  Brown_26005_1    rest_1
# 23   26005  Brown        1  Brown_26005_1    anat_1
# 26   26009  Brown        1  Brown_26009_1    rest_1
# 27   26009  Brown        1  Brown_26009_1    anat_1
# 30   26002  Brown        1  Brown_26002_1    rest_1
# 31   26002  Brown        1  Brown_26002_1    anat_1
# 32   26001  Brown        1  Brown_26001_1    rest_1
# 33   26001  Brown        1  Brown_26001_1    anat_1
# 34   26004  Brown        1  Brown_26004_1    rest_1
# 35   26004  Brown        1  Brown_26004_1    anat_1
# 44   26017  Brown        1  Brown_26017_1    rest_1
# 45   26017  Brown        1  Brown_26017_1    anat_1
# 50   26016  Brown        1  Brown_26016_1    rest_1
# 51   26016  Brown        1  Brown_26016_1    anat_1
# 63   26015  Brown        1  Brown_26015_1    rest_1
# 64   26015  Brown        1  Brown_26015_1    anat_1
# 69   26014  Brown        1  Brown_26014_1    rest_1
# 70   26014  Brown        1  Brown_26014_1    anat_1
# 83   26027  Brown        1  Brown_26027_1    rest_1
# 84   26027  Brown        1  Brown_26027_1    anat_1
# 91   26022  Brown        1  Brown_26022_1    rest_1
# 92   26022  Brown        1  Brown_26022_1    anat_1
# 97   26024  Brown        1  Brown_26024_1    rest_1
# 98   26024  Brown        1  Brown_26024_1    anat_1
# 101  26040  Brown        1  Brown_26040_1    rest_1
# 102  26040  Brown        1  Brown_26040_1    anat_1
# 109  26039  Brown        1  Brown_26039_1    rest_1
# 110  26039  Brown        1  Brown_26039_1    anat_1
# 119  26030  Brown        1  Brown_26030_1    rest_1
# 120  26030  Brown        1  Brown_26030_1    anat_1
# 131  26050  Brown        1  Brown_26050_1    rest_1
# 132  26050  Brown        1  Brown_26050_1    anat_1
# 160  26042  Brown        1  Brown_26042_1    rest_1
# 161  26042  Brown        1  Brown_26042_1    anat_1
# 164  26041  Brown        1  Brown_26041_1    rest_1
# 165  26041  Brown        1  Brown_26041_1    anat_1
# 169  26044  Brown        1  Brown_26044_1    rest_1
# 170  26044  Brown        1  Brown_26044_1    anat_1
# 174  26043  Brown        1  Brown_26043_1    rest_1
# 175  26043  Brown        1  Brown_26043_1    anat_1
# 188  26045  Brown        1  Brown_26045_1    rest_1
# 189  26045  Brown        1  Brown_26045_1    anat_1
# 225  26053  Brown        1  Brown_26053_1    rest_1
# 226  26053  Brown        1  Brown_26053_1    anat_1
# 227  26052  Brown        1  Brown_26052_1    rest_1
# 228  26052  Brown        1  Brown_26052_1    anat_1
# 232  26055  Brown        1  Brown_26055_1    rest_1
# 233  26055  Brown        1  Brown_26055_1    anat_1
# 234  26054  Brown        1  Brown_26054_1    rest_1
# 235  26054  Brown        1  Brown_26054_1    anat_1
# 239  26057  Brown        1  Brown_26057_1    rest_1
# 240  26057  Brown        1  Brown_26057_1    anat_1
#
#                                              file_path  ScanDir ID  Site  \
# 22   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26005     2
# 23   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26005     2
# 26   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26009     2
# 27   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26009     2
# 30   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26002     2
# 31   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26002     2
# 32   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26001     2
# 33   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26001     2
# 34   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26004     2
# 35   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26004     2
# 44   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26017     2
# 45   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26017     2
# 50   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26016     2
# 51   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26016     2
# 63   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26015     2
# 64   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26015     2
# 69   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26014     2
# 70   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26014     2
# 83   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26027     2
# 84   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26027     2
# 91   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26022     2
# 92   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26022     2
# 97   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26024     2
# 98   /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26024     2
# 101  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26040     2
# 102  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26040     2
# 109  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26039     2
# 110  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26039     2
# 119  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26030     2
# 120  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26030     2
# 131  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26050     2
# 132  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26050     2
# 160  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26042     2
# 161  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26042     2
# 164  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26041     2
# 165  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26041     2
# 169  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26044     2
# 170  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26044     2
# 174  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26043     2
# 175  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26043     2
# 188  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26045     2
# 189  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26045     2
# 225  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26053     2
# 226  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26053     2
# 227  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26052     2
# 228  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26052     2
# 232  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26055     2
# 233  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26055     2
# 234  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26054     2
# 235  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26054     2
# 239  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26057     2
# 240  /Volumes/Expansion/ADHD/yomo-20231204_124111/B...       26057     2
#
#      Gender    Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 22      0.0  15.16  ...         pending        NaN     116.0          131.0
# 23      0.0  15.16  ...         pending        NaN     116.0          131.0
# 26      1.0  16.91  ...         pending        NaN     113.0           81.0
# 27      1.0  16.91  ...         pending        NaN     113.0           81.0
# 30      1.0  15.68  ...         pending        NaN     106.0          106.0
# 31      1.0  15.68  ...         pending        NaN     106.0          106.0
# 32      1.0  16.92  ...         pending        NaN     133.0          104.0
# 33      1.0  16.92  ...         pending        NaN     133.0          104.0
# 34      0.0  14.99  ...         pending        NaN     119.0          123.0
# 35      0.0  14.99  ...         pending        NaN     119.0          123.0
# 44      0.0  14.56  ...         pending        NaN      95.0           87.0
# 45      0.0  14.56  ...         pending        NaN      95.0           87.0
# 50      1.0  16.07  ...         pending        NaN     120.0           96.0
# 51      1.0  16.07  ...         pending        NaN     120.0           96.0
# 63      0.0  15.20  ...         pending        NaN     127.0           98.0
# 64      0.0  15.20  ...         pending        NaN     127.0           98.0
# 69      0.0  16.21  ...         pending        NaN     101.0          102.0
# 70      0.0  16.21  ...         pending        NaN     101.0          102.0
# 83      0.0  11.28  ...         pending        NaN     108.0          103.0
# 84      0.0  11.28  ...         pending        NaN     108.0          103.0
# 91      1.0  17.83  ...         pending        NaN     105.0          111.0
# 92      1.0  17.83  ...         pending        NaN     105.0          111.0
# 97      0.0  17.77  ...         pending        NaN      89.0           83.0
# 98      0.0  17.77  ...         pending        NaN      89.0           83.0
# 101     0.0  13.67  ...         pending        NaN     111.0           93.0
# 102     0.0  13.67  ...         pending        NaN     111.0           93.0
# 109     0.0  14.19  ...         pending        NaN     125.0          117.0
# 110     0.0  14.19  ...         pending        NaN     125.0          117.0
# 119     0.0  14.51  ...         pending        NaN     121.0          119.0
# 120     0.0  14.51  ...         pending        NaN     121.0          119.0
# 131     0.0   8.50  ...         pending        NaN     121.0          116.0
# 132     0.0   8.50  ...         pending        NaN     121.0          116.0
# 160     0.0  13.82  ...         pending        NaN     106.0          110.0
# 161     0.0  13.82  ...         pending        NaN     106.0          110.0
# 164     0.0  13.68  ...         pending        NaN     129.0          120.0
# 165     0.0  13.68  ...         pending        NaN     129.0          120.0
# 169     0.0   9.32  ...         pending        NaN     119.0           93.0
# 170     0.0   9.32  ...         pending        NaN     119.0           93.0
# 174     0.0  11.60  ...         pending        NaN     125.0          127.0
# 175     0.0  11.60  ...         pending        NaN     125.0          127.0
# 188     1.0  14.67  ...         pending        NaN     109.0          109.0
# 189     1.0  14.67  ...         pending        NaN     109.0          109.0
# 225     1.0  15.79  ...         pending        NaN     123.0          111.0
# 226     1.0  15.79  ...         pending        NaN     123.0          111.0
# 227     0.0  17.87  ...         pending        NaN     111.0          109.0
# 228     0.0  17.87  ...         pending        NaN     111.0          109.0
# 232     1.0  17.74  ...         pending        NaN     109.0          119.0
# 233     1.0  17.74  ...         pending        NaN     109.0          119.0
# 234     0.0  12.02  ...         pending        NaN     136.0          109.0
# 235     0.0  12.02  ...         pending        NaN     136.0          109.0
# 239     1.0  12.00  ...         pending        NaN     114.0          110.0
# 240     1.0  12.00  ...         pending        NaN     114.0          110.0
#
#     Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 22       NaN    126.0    pending        1.0      1.0        NaN
# 23       NaN    126.0    pending        1.0      1.0        NaN
# 26       NaN     97.0    pending        1.0      1.0        NaN
# 27       NaN     97.0    pending        1.0      1.0        NaN
# 30       NaN    107.0    pending        1.0      1.0        NaN
# 31       NaN    107.0    pending        1.0      1.0        NaN
# 32       NaN    120.0    pending        1.0      1.0        NaN
# 33       NaN    120.0    pending        1.0      1.0        NaN
# 34       NaN    125.0    pending        1.0      1.0        NaN
# 35       NaN    125.0    pending        1.0      1.0        NaN
# 44       NaN     89.0    pending        1.0      1.0        NaN
# 45       NaN     89.0    pending        1.0      1.0        NaN
# 50       NaN    109.0    pending        1.0      1.0        NaN
# 51       NaN    109.0    pending        1.0      1.0        NaN
# 63       NaN    113.0    pending        1.0      1.0        NaN
# 64       NaN    113.0    pending        1.0      1.0        NaN
# 69       NaN    102.0    pending        1.0      1.0        NaN
# 70       NaN    102.0    pending        1.0      1.0        NaN
# 83       NaN    106.0    pending        1.0      1.0        NaN
# 84       NaN    106.0    pending        1.0      1.0        NaN
# 91       NaN    109.0    pending        1.0      1.0        NaN
# 92       NaN    109.0    pending        1.0      1.0        NaN
# 97       NaN     85.0    pending        1.0      1.0        NaN
# 98       NaN     85.0    pending        1.0      1.0        NaN
# 101      NaN    102.0    pending        1.0      1.0        NaN
# 102      NaN    102.0    pending        1.0      1.0        NaN
# 109      NaN    124.0    pending        1.0      1.0        NaN
# 110      NaN    124.0    pending        1.0      1.0        NaN
# 119      NaN    123.0    pending        0.0      1.0        NaN
# 120      NaN    123.0    pending        0.0      1.0        NaN
# 131      NaN    121.0    pending        1.0      1.0        NaN
# 132      NaN    121.0    pending        1.0      1.0        NaN
# 160      NaN    109.0    pending        1.0      1.0        NaN
# 161      NaN    109.0    pending        1.0      1.0        NaN
# 164      NaN    128.0    pending        1.0      1.0        NaN
# 165      NaN    128.0    pending        1.0      1.0        NaN
# 169      NaN    107.0    pending        1.0      1.0        NaN
# 170      NaN    107.0    pending        1.0      1.0        NaN
# 174      NaN    129.0    pending        1.0      1.0        NaN
# 175      NaN    129.0    pending        1.0      1.0        NaN
# 188      NaN    111.0    pending        1.0      1.0        NaN
# 189      NaN    111.0    pending        1.0      1.0        NaN
# 225      NaN    120.0    pending        1.0      1.0        NaN
# 226      NaN    120.0    pending        1.0      1.0        NaN
# 227      NaN    112.0    pending        1.0      1.0        NaN
# 228      NaN    112.0    pending        1.0      1.0        NaN
# 232      NaN    116.0    pending        1.0      1.0        NaN
# 233      NaN    116.0    pending        1.0      1.0        NaN
# 234      NaN    125.0    pending        1.0      1.0        NaN
# 235      NaN    125.0    pending        1.0      1.0        NaN
# 239      NaN    114.0    pending        1.0      1.0        NaN
# 240      NaN    114.0    pending        1.0      1.0        NaN
#
# [52 rows x 26 columns]

# %%
unique_values_count = nan_rows['ID'].nunique()

print(f"Number of unique values in 'ID': {unique_values_count}")
# Out:
# Number of unique values in 'ID': 26

# %%
filtered_rows['site'].value_counts()
# Out:
# site
# WashU    11
# Name: count, dtype: int64

# %% [markdown]
# We need to eliminate from the data frame the subjects that have no diagnosis/ label, and the ones that have had more than one scan session.

# %%
# we started off with 1953 rows
cleaned.shape
# Out:
# (1341, 26)

# %%
cleaned.head()
# Out:
#         ID        site  session          combinedData scan_type  \
# 0  4020830  NeuroIMAGE        1  NeuroIMAGE_4020830_1    rest_1
# 1  4020830  NeuroIMAGE        1  NeuroIMAGE_4020830_1    anat_1
# 2  3248920      Peking        1      Peking_3248920_1    rest_1
# 3  3248920      Peking        1      Peking_3248920_1    anat_1
# 4  3767334      Peking        1      Peking_3767334_1    rest_1
#
#                                            file_path  ScanDir ID  Site  \
# 0  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...     4020830     4
# 1  /Volumes/Expansion/ADHD/yomo-20231204_124111/N...     4020830     4
# 2  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3248920     1
# 3  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3248920     1
# 4  /Volumes/Expansion/ADHD/yomo-20231204_124111/P...     3767334     1
#
#    Gender    Age  ... Hyper/Impulsive IQ Measure Verbal IQ Performance IQ  \
# 0     0.0  18.19  ...             NaN        NaN       NaN            NaN
# 1     0.0  18.19  ...             NaN        NaN       NaN            NaN
# 2     1.0  12.17  ...              10        3.0    -999.0         -999.0
# 3     1.0  12.17  ...              10        3.0    -999.0         -999.0
# 4     1.0   8.33  ...              25        3.0     112.0          104.0
#
#   Full2 IQ Full4 IQ Med Status  QC_Athena  QC_NIAK  diagnosis
# 0      NaN      NaN        NaN        1.0      1.0        0.0
# 1      NaN      NaN        NaN        1.0      1.0        0.0
# 2      NaN   -999.0          1        1.0      1.0        0.0
# 3      NaN   -999.0          1        1.0      1.0        0.0
# 4   -999.0    109.0          1        1.0      1.0        1.0
#
# [5 rows x 26 columns]

# %%
# removing 52 rows with missign diagnosis
cleaned_df = cleaned.dropna(subset=['diagnosis'])

# %%
cleaned_df.shape
# Out:
# (1289, 26)

# %%
ids_with_multiple_sessions = cleaned_df[cleaned_df['session'] > 1]['ID'].unique()
print(len(ids_with_multiple_sessions))
ids_with_multiple_sessions
# Out:
# 10
# array([15022, 15021, 15024, 15023, 15011, 15013, 15014, 15017, 15016,
#        15019])

# %%
# Filter the DataFrame to only include rows with these IDs
rows_with_multiple_sessions = cleaned_df[cleaned_df['ID'].isin(ids_with_multiple_sessions)]

# %%
rows_with_multiple_sessions['site'].value_counts()
# Out:
# site
# WashU    29
# Name: count, dtype: int64

# %%
# Remove rows with these IDs from the cleaned_df
cleaned_df = cleaned_df[~cleaned_df['ID'].isin(ids_with_multiple_sessions)]

# %%
# Cleaned data end result
cleaned_df.shape
# Out:
# (1260, 26)

# %%
cleaned_df['scan_type'].value_counts()
# Out:
# scan_type
# anat_1    633
# rest_1    627
# Name: count, dtype: int64

# %%
# Unique count of health controls and ADHD cases in the cleaned dataset
unique_IDs = cleaned_df.drop_duplicates(subset='ID')

# Count of unique health controls (diagnosis = 0) and ADHD (diagnosis = 1)
unique_health_controls_count = unique_IDs[unique_IDs['diagnosis'] == 0].shape[0]
unique_adhd_count = unique_IDs[unique_IDs['diagnosis'] == 1].shape[0]

print("Unique health controls count:", unique_health_controls_count)
print("Unique ADHD count:", unique_adhd_count)
# Out:
# Unique health controls count: 402
# Unique ADHD count: 231

# %%
# Export the results to use in the next steps
cleaned_df.to_csv('/Volumes/Expansion/ADHD/yomo-20231204_124111/cleaned_df.csv', index=False)
